# %%
import geopandas as gpd
import pandas as pd
import numpy as np

from shapely.geometry import MultiPolygon
from shapely.prepared import prep
from scipy.spatial import cKDTree

# %%
wrecks_df = pd.read_excel("data/shipwrecks_with_bermuda.xlsx")
wrecks_df.head()
# Out:
#                       date        lat        lon                      near  \
# 0      1996-05-13 05:50:00  40.876665 -91.031665  United States of America
# 1      1996-05-13 05:50:01  40.876665 -91.031665  United States of America
# 2      1996-05-13 05:50:01  40.876665 -91.031665  United States of America
# 3      1996-05-13 05:50:02  40.876665 -91.031665  United States of America
# 4      1996-05-13 05:50:02  40.876665 -91.031665  United States of America
# ...                    ...        ...        ...                       ...
# 106261 2015-06-22 14:10:01  37.310490 -89.513615  United States of America
# 106262 2015-06-22 16:35:00  25.760800 -79.956670  United States of America
# 106263 2015-06-22 16:35:00  25.760800 -79.956670  United States of America
# 106264 2015-06-24 13:52:00  29.732314 -95.127879  United States of America
# 106265 2015-06-24 13:53:00  29.732314 -95.127879  United States of America
#
#         in_bermuda
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 106261       False
# 106262        True
# 106263        True
# 106264       False
# 106265       False
#
# [106266 rows x 5 columns]

# %%
worldmap = gpd.read_file(
    "data/natural_earth/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp"
).to_crs("EPSG:3857")[["NAME", "geometry"]].rename(columns={"NAME": "country"})
country_geometry = {n: g for n, g in zip(worldmap.country, worldmap.geometry)}
wrecks_gdf = gpd.GeoDataFrame(
    wrecks_df,
    geometry=gpd.points_from_xy(wrecks_df.lon, wrecks_df.lat),
    crs="EPSG:4326"
).to_crs("EPSG:3857")

def distance_to_coast(row):
    poly = country_geometry.get(row.near)
    if poly is None or row.geometry is None:
        return np.nan
    pt = row.geometry
    if isinstance(poly, MultiPolygon):
        parts = list(poly.geoms)
        poly = min(parts, key=lambda p: pt.distance(p))
    prepared = prep(poly)
    if prepared.contains(pt):
        return pt.distance(poly.boundary)
    return pt.distance(poly)

wrecks_gdf["m_to_coast"] = wrecks_gdf.apply(distance_to_coast, axis=1)
wrecks_gdf["km_to_coast"] = wrecks_gdf["m_to_coast"] / 1000
wrecks_df = wrecks_gdf[["date", "lat", "lon", "near", "in_bermuda", "km_to_coast"]].copy()
print(wrecks_df["km_to_coast"].describe())
# Out:
# count    106266.000000
# mean        204.584209
# std        1040.508657
# min           0.000581
# 25%           1.680167
# 50%          13.765298
# 75%         305.725243
# max      224099.958016
# Name: km_to_coast, dtype: float64

# %%
wrecks_df.to_excel("data/shipwrecks_with_distance_to_coast.xlsx", index=False)

# %% [markdown]
# ***

# %%
wrecks_df = pd.read_excel("data/shipwrecks_with_distance_to_coast.xlsx")
wrecks_df.head()
# Out:
#                  date        lat        lon                      near  \
# 0 1996-05-13 05:50:00  40.876665 -91.031665  United States of America
# 1 1996-05-13 05:50:01  40.876665 -91.031665  United States of America
# 2 1996-05-13 05:50:01  40.876665 -91.031665  United States of America
# 3 1996-05-13 05:50:02  40.876665 -91.031665  United States of America
# 4 1996-05-13 05:50:02  40.876665 -91.031665  United States of America
#
#    in_bermuda  km_to_coast
# 0       False    892.34512
# 1       False    892.34512
# 2       False    892.34512
# 3       False    892.34512
# 4       False    892.34512

# %%
wrecks_df.shape
# Out:
# (106266, 6)

# %%
wrecks_gdf = gpd.GeoDataFrame(
    wrecks_df,
    geometry=gpd.points_from_xy(wrecks_df.lon, wrecks_df.lat),
    crs="EPSG:4326"
).to_crs("EPSG:3857")

def distance_to_neighbor(row):
    dists = wrecks_gdf.distance(row.geometry)
    return dists.drop(row.name).min()

wrecks_gdf["m_to_neighbor"] = wrecks_gdf.apply(distance_to_neighbor, axis=1)
wrecks_gdf["km_to_neighbor"] = wrecks_gdf["m_to_neighbor"] / 1000
print(wrecks_df["km_to_neighbor"].describe())

# %%
wrecks_gdf = gpd.GeoDataFrame(
    wrecks_df,
    geometry=gpd.points_from_xy(wrecks_df.lon, wrecks_df.lat),
    crs="EPSG:4326"
).to_crs("EPSG:3857")

coords = np.column_stack((wrecks_gdf.geometry.x, wrecks_gdf.geometry.y))
tree = cKDTree(coords)

k = 5
dists, _ = tree.query(coords, k=k)

wrecks_gdf["m_to_neighbor"] = dists.max(axis=1)
wrecks_gdf["km_to_neighbor"] = wrecks_gdf["m_to_neighbor"] / 1000

wrecks_df["km_to_neighbor"] = wrecks_gdf["km_to_neighbor"]
print(wrecks_df["km_to_neighbor"].describe())
# Out:
# count    106266.000000
# mean         14.050359
# std         855.066016
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.926336
# max      192695.986086
# Name: km_to_neighbor, dtype: float64

# %%
wrecks_df.head(20)
# Out:
#                   date        lat         lon                      near  \
# 0  1996-05-13 05:50:00  40.876665  -91.031665  United States of America
# 1  1996-05-13 05:50:01  40.876665  -91.031665  United States of America
# 2  1996-05-13 05:50:01  40.876665  -91.031665  United States of America
# 3  1996-05-13 05:50:02  40.876665  -91.031665  United States of America
# 4  1996-05-13 05:50:02  40.876665  -91.031665  United States of America
# 5  1996-05-13 05:50:03  40.876665  -91.031665  United States of America
# 6  1996-05-13 05:50:04  40.876665  -91.031665  United States of America
# 7  1996-05-13 05:50:04  40.876665  -91.031665  United States of America
# 8  1996-05-15 16:00:00  48.414370 -122.596000  United States of America
# 9  1996-05-15 16:00:00  48.400000 -122.500000  United States of America
# 10 1996-05-15 16:00:00  48.400000 -122.500000  United States of America
# 11 1996-11-05 17:25:00  47.600000 -122.316666  United States of America
# 12 1997-03-01 13:40:00  38.586666  -90.211666  United States of America
# 13 1997-03-01 13:41:00  38.586666  -90.211666  United States of America
# 14 1997-03-01 13:42:00  38.586666  -90.211666  United States of America
# 15 1997-03-01 13:43:00  38.586666  -90.211666  United States of America
# 16 1997-03-29 14:30:00  27.950000  -82.583333  United States of America
# 17 1997-04-22 02:00:00  42.886666  -86.639999  United States of America
# 18 1997-04-22 02:00:00  42.886666  -86.639999  United States of America
# 19 1997-11-06 09:15:00  13.760000  144.421666                      Guam
#
#     in_bermuda  km_to_coast  km_to_neighbor
# 0        False   892.345120        0.000000
# 1        False   892.345120        0.000000
# 2        False   892.345120        0.000000
# 3        False   892.345120        0.000000
# 4        False   892.345120        0.000000
# 5        False   892.345120        0.000000
# 6        False   892.345120        0.000000
# 7        False   892.345120        0.000000
# 8        False     1.268124        8.543968
# 9        False     5.248746        1.842866
# 10       False     5.248746        1.842866
# 11       False     2.602912        1.855399
# 12       False   925.937379        0.204475
# 13       False   925.937379        0.204475
# 14       False   925.937379        0.204475
# 15       False   925.937379        0.204475
# 16       False     1.275189        7.054645
# 17       False   402.932411       38.340484
# 18       False   402.932411       38.340484
# 19       False    43.409939        0.000000

# %%
wrecks_df.to_excel("data/shipwrecks_with_distance_to_neighbor.xlsx", index=False)
